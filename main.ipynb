# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import random
from openai import OpenAI
import cProfile
from GNBG_instances import get_gnbg
from deepseek import get_rmp_update_code

# %%
np.random.seed(0)
np.set_printoptions(legacy='1.25')

# %%
class MFEA:
    def __init__(self, pop_size, indi_len, tasks):
        self.pop_size = pop_size
        self.indi_len = indi_len
        self.pop = np.random.uniform(-100.0, 100.0, size=(self.pop_size, self.indi_len))
        self.tasks = tasks
        self.num_tasks = len(tasks)
        self.rmp_update_code = ""
        self.skill_factor = np.zeros(self.pop_size, dtype=int)
    
        for i in range(self.pop_size):
            self.skill_factor[i] = i % self.num_tasks
        
        self.fitness = np.zeros(pop_size)
        self.mean_fitness = np.zeros(self.num_tasks)
        self.best_fitness = np.zeros(self.num_tasks)
        
        for task_id in range(self.num_tasks):
            task_mask = self.skill_factor == task_id
            self.fitness[task_mask] = self.tasks[task_id].fitness(self.pop[task_mask])
            self.mean_fitness[task_id] = np.mean(self.fitness[task_mask])
            self.best_fitness[task_id] = np.min(self.fitness[task_mask])

            print("Task {0}:".format(task_id))
            print("Mean Fitness At Initiation: {0}".format(self.mean_fitness[task_id]))
            print("Best Fitness At Initiation: {0}".format(self.best_fitness[task_id]))
            print("--------------------------------")
        self.cur_rmp = 0
        self.success_rate = 0

    def get_rmp_llm(self, get_new_code=False):
        if get_new_code == True:
            while True:
                try:
                    code = get_rmp_update_code()
                    print(code)
                    f = {}
                    exec(code, f)
                    rmp = f['get_rmp'](self.pop, self.fitness, self.skill_factor)
                    break
                except Exception as e:
                    print("Bad Function Generated!")
            self.rmp_update_code = code
            return rmp
        else:
            code = self.rmp_update_code
            f = {}
            exec(code, f)
            rmp = f['get_rmp'](self.pop, self.fitness, self.skill_factor)
        
        return rmp
    
    def get_rmp(self):
        return np.random.choice([0.3, 0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1.0], size=(self.pop_size, self.pop_size))

    def crossover(self, p1, p2):
        off = p1.copy()
        num_swap_pos = int(self.indi_len / 6)

        t = np.arange(len(off), dtype=np.int32) # t = [0, 1, 2, ... (len(off) - 1)]
        row_indices = np.lib.stride_tricks.as_strided(t, shape=(len(off), num_swap_pos), strides=(4, 0))
        
        swap_pos = np.random.randint(0, self.indi_len, size=(len(off), num_swap_pos))
        
        off[row_indices, swap_pos] = p2[row_indices, swap_pos]
        return off

    def mutate(self, p):
        off = p.copy()
        delta = np.random.uniform(-2, 2, size=off.shape)
        off += delta
        off[np.where(off > 100.0)] = 100.0
        off[np.where(off < -100.0)] = -100.0
        return off
    
    def run(self, num_gen, update_rmp=False, rf=0, llm=False, llm_rate=50):
        num_off = int(self.pop_size / 5)

        for gen in range(num_gen + 1):
            start_time = time.time()
            p1_indices = np.random.randint(0, self.pop_size, size=num_off)
            p2_indices = np.random.randint(0, self.pop_size, size=num_off)

            p1 = self.pop[p1_indices]
            p2 = self.pop[p2_indices]
            
            p1_skill_factor = self.skill_factor[p1_indices]
            p2_skill_factor = self.skill_factor[p2_indices]

            if llm == False:
                rmp = self.get_rmp()
            if llm == True:
                if gen % llm_rate == 0:
                    rmp = self.get_rmp_llm(get_new_code=True)
                else:
                    rmp = self.get_rmp_llm(get_new_code=False)
            self.cur_rmp = rmp
            
            intra_crossover_mask = np.equal(p1_skill_factor, p2_skill_factor)
            inter_crossover_mask = np.not_equal(p1_skill_factor, p2_skill_factor)
            
            intra_off = self.crossover(p1[intra_crossover_mask], p2[intra_crossover_mask]) #intra-mating
            intra_skill_factor = p1_skill_factor[intra_crossover_mask]

            rmp_values = rmp[p1_indices, p2_indices]
            
            rnd = np.random.uniform(size=len(p1_indices))
            
            rmp_accept_mask = np.greater(rmp_values, rnd) & inter_crossover_mask
            
            p1_inter_indices = p1_indices[rmp_accept_mask]
            p2_inter_indices = p2_indices[rmp_accept_mask]

            inter_off = self.crossover(self.pop[p1_inter_indices], self.pop[p2_inter_indices]) #inter-mating
            inter_skill_factor = self.skill_factor[p1_inter_indices]

            mutate_mask = np.invert(np.greater(rmp_values, rnd)) & inter_crossover_mask
            mutate_off_1 = self.mutate(p1[mutate_mask])
            mutate_off_2 = self.mutate(p2[mutate_mask])
            mutate_skill_factor_1 = p1_skill_factor[mutate_mask]
            mutate_skill_factor_2 = p2_skill_factor[mutate_mask]
            mutate_off = np.concatenate([mutate_off_1, mutate_off_2])
            mutate_skill_factor = np.concatenate([mutate_skill_factor_1, mutate_skill_factor_2])

            intermediate_pop = np.concatenate([self.pop, intra_off, inter_off, mutate_off])
            intermediate_skill_factor = np.concatenate([self.skill_factor, intra_skill_factor, inter_skill_factor, mutate_skill_factor])

            self.pop = np.array([]).reshape(0, self.indi_len)
            self.fitness = []
            self.skill_factor = []

            for task_id in range(self.num_tasks):
                survive_size = int(self.pop_size / self.num_tasks)
                task_mask = intermediate_skill_factor == task_id
                tpop = intermediate_pop[task_mask] #pop with specific task
                tpop_fitness = self.tasks[task_id].fitness(tpop)

                self.best_fitness[task_id] = np.min(tpop_fitness)
                survive_indices = np.argpartition(tpop_fitness, survive_size - 1)[:survive_size]
                self.mean_fitness[task_id] = np.mean(tpop_fitness[survive_indices])

                self.pop = np.concatenate([self.pop, tpop[survive_indices]])
                self.fitness = np.concatenate([self.fitness, tpop_fitness[survive_indices]])
                self.skill_factor = np.concatenate([self.skill_factor, np.full(survive_size, task_id)])
            assert(len(self.pop) == self.pop_size)
            if gen % 20 == 0:
                print("Gen {0}:".format(gen))
                for task_id in range(self.num_tasks):
                    print("Task {0}:".format(task_id))
                    print("    Best Fitness: {0}".format(self.best_fitness[task_id]))
                    print("    Mean Fitness: {0}".format(self.mean_fitness[task_id]))
                print(psutil.Process().memory_info().rss / (1024 * 1024))
                print("--- %.2f seconds ---" % (time.time() - start_time))

# %%
def get_tasks(task_ids):
    tasks = []
    for task_id in task_ids:
        tasks.append(get_gnbg(task_id))
    return tasks

# %%
tasks = get_tasks([1, 2, 9, 10, 17, 18])

# %%
pop_size = len(tasks) * 200
mfea = MFEA(pop_size, 30, tasks)
# Out:
# Task 0:
# Mean Fitness At Initiation: 169958.07923376016
# Best Fitness At Initiation: 85062.7776468086
# --------------------------------
# Task 1:
# Mean Fitness At Initiation: -701.3087036303684
# Best Fitness At Initiation: -701.3662124426851
# --------------------------------
# Task 2:
# Mean Fitness At Initiation: 1697336.6918461781
# Best Fitness At Initiation: 126127.42688156506
# --------------------------------
# Task 3:
# Mean Fitness At Initiation: 214562.79304379114
# Best Fitness At Initiation: 73119.64940517231
# --------------------------------
# Task 4:
# Mean Fitness At Initiation: 6858154.221528683
# Best Fitness At Initiation: 3722293.7724119285
# --------------------------------
# Task 5:
# Mean Fitness At Initiation: 156139.79262626817
# Best Fitness At Initiation: 57369.79069691928
# --------------------------------

# %%
mfea.run(500, llm=True)
# Out:
# import numpy as np
#
# def get_rmp(pop, fitness, skill_factor):
#     n = len(pop)
#     task_indices = [np.where(skill_factor == i)[0] for i in np.unique(skill_factor)]
#     num_tasks = len(task_indices)
#
#     rmp = np.zeros((n, n))
#
#     for i in range(num_tasks):
#         for j in range(i, num_tasks):
#             idx_i = task_indices[i]
#             idx_j = task_indices[j]
#
#             if i == j:
#                 rmp[np.ix_(idx_i, idx_j)] = 1.0
#             else:
#                 pop_i = pop[idx_i]
#                 pop_j = pop[idx_j]
#
#                 distances = np.sqrt(np.sum((pop_i[:, np.newaxis] - pop_j) ** 2, axis=2))
#                 max_dist = np.max(distances)
#                 normalized_dist = distances / max_dist
#
#                 fitness_i = fitness[idx_i]
#                 fitness_j = fitness[idx_j]
#                 fit_diff = np.abs(fitness_i[:, np.newaxis] - fitness_j)
#                 max_fit_diff = np.max(fit_diff)
#                 normalized_fit = 1 - (fit_diff / max_fit_diff)
#
#                 combined = 0.5 * (normalized_dist + normalized_fit)
#                 rmp_ij = 0.5 * (1 + np.tanh(2 * combined - 1))
#
#                 rmp[np.ix_(idx_i, idx_j)] = rmp_ij
#                 rmp[np.ix_(idx_j, idx_i)] = rmp_ij.T
#
#     np.fill_diagonal(rmp, 1.0)
#     return rmp
# Gen 0:
# Task 0:
#     Best Fitness: 76609.06280138968
#     Mean Fitness: 155187.19070621335
# Task 1:
#     Best Fitness: -701.3683881889598
#     Mean Fitness: -701.3168531578227
# 172.95703125
# --- 22.94 seconds ---
# Gen 20:
# Task 0:
#     Best Fitness: 46894.796792001376
#     Mean Fitness: 77773.87392084199
# Task 1:
#     Best Fitness: -701.4061489727811
#     Mean Fitness: -701.3702082463792
# 173.984375
# --- 0.06 seconds ---
# Gen 40:
# Task 0:
#     Best Fitness: 25470.5355389234
#     Mean Fitness: 44979.22566686621
# Task 1:
#     Best Fitness: -701.4930301291131
#     Mean Fitness: -701.4197366913613
# 172.890625
# --- 0.08 seconds ---
# import numpy as np
#
# def get_rmp(pop, fitness, skill_factor):
#     num_tasks = len(np.unique(skill_factor))
#     num_individuals = pop.shape[0]
#
#     same_task_mask = skill_factor[:, np.newaxis] == skill_factor[np.newaxis, :]
#
#     normalized_pop = (pop - np.min(pop, axis=0)) / (np.max(pop, axis=0) - np.min(pop, axis=0) + 1e-10)
#     distances = np.sqrt(np.sum((normalized_pop[:, np.newaxis, :] - normalized_pop[np.newaxis, :, :])**2, axis=-1))
#     max_dist = np.max(distances)
#     normalized_distances = distances / max_dist if max_dist != 0 else distances
#
#     rmp = np.ones((num_individuals, num_individuals))
#
#     fitness_ratio = fitness[:, np.newaxis] / fitness[np.newaxis, :]
#     fitness_ratio = np.minimum(fitness_ratio, 1.0 / fitness_ratio)
#
#     cross_task_mask = ~same_task_mask
#     rmp[cross_task_mask] = 0.5 * (1 - normalized_distances[cross_task_mask]) * fitness_ratio[cross_task_mask]
#
#     rmp = np.clip(rmp, 0.05, 0.95)
#     np.fill_diagonal(rmp, 1.0)
#
#     return rmp
# Gen 60:
# Task 0:
#     Best Fitness: 16190.016316556983
#     Mean Fitness: 23431.902916774216
# Task 1:
#     Best Fitness: -701.5185233363777
#     Mean Fitness: -701.4872409371429
# 173.4921875
# --- 0.08 seconds ---
# Gen 80:
# Task 0:
#     Best Fitness: 8310.108573100391
#     Mean Fitness: 11662.09666236585
# Task 1:
#     Best Fitness: -701.5394124428533
#     Mean Fitness: -701.5240400199496
# 172.796875
# --- 0.08 seconds ---
# import numpy as np
#
# def get_rmp(pop, fitness, skill_factor):
#     num_tasks = len(np.unique(skill_factor))
#     population_size = len(pop)
#     rmp = np.zeros((population_size, population_size))
#
#     same_task_mask = skill_factor[:, None] == skill_factor[None, :]
#     diff_task_mask = ~same_task_mask
#
#     distances = np.sqrt(np.sum((pop[:, None, :] - pop[None, :, :]) ** 2, axis=2))
#     normalized_dist = (distances - np.min(distances)) / (np.max(distances) - np.min(distances) + 1e-10)
#
#     fitness_diff = np.abs(fitness[:, None] - fitness[None, :])
#     normalized_fitness = (fitness_diff - np.min(fitness_diff)) / (np.max(fitness_diff) - np.min(fitness_diff) + 1e-10)
#
#     rmp_base = np.exp(-normalized_dist) * np.exp(-normalized_fitness)
#     rmp_base = np.clip(rmp_base, 0.1, 0.9)
#
#     rmp[same_task_mask] = 1.0
#     rmp[diff_task_mask] = rmp_base[diff_task_mask]
#
#     return rmp
# Gen 100:
# Task 0:
#     Best Fitness: 3372.5431002842106
#     Mean Fitness: 6332.566622585101
# Task 1:
#     Best Fitness: -701.5612785764993
#     Mean Fitness: -701.5461170387639
# 172.8203125
# --- 15.97 seconds ---
# Gen 120:
# Task 0:
#     Best Fitness: 2375.402533198164
#     Mean Fitness: 3622.736898110402
# Task 1:
#     Best Fitness: -701.5736126485632
#     Mean Fitness: -701.5641654972461
# 173.82421875
# --- 0.09 seconds ---
# Gen 140:
# Task 0:
#     Best Fitness: 1697.1388914671163
#     Mean Fitness: 2281.3725238101515
# Task 1:
#     Best Fitness: -701.5921954644765
#     Mean Fitness: -701.5788083348098
# 173.8359375
# --- 0.10 seconds ---
# import numpy as np
#
# def get_rmp(pop, fitness, skill_factor):
#     num_individuals = pop.shape[0]
#     rmp = np.zeros((num_individuals, num_individuals))
#
#     same_task = skill_factor[:, None] == skill_factor
#     diff_task = ~same_task
#
#     dist = np.sqrt(np.sum((pop[:, None, :] - pop[None, :, :]) ** 2, axis=-1))
#     norm_dist = dist / np.max(dist)
#
#     fitness_diff = np.abs(fitness[:, None] - fitness[None, :])
#     norm_fitness_diff = fitness_diff / np.max(fitness_diff)
#
#     rmp_base = 1.0 - norm_dist
#     rmp_penalty = 0.5 * norm_fitness_diff
#
#     rmp = np.where(diff_task, rmp_base - rmp_penalty, 1.0)
#     rmp = np.clip(rmp, 0.1, 0.9)
#     np.fill_diagonal(rmp, 1.0)
#
#     return rmp
# Gen 160:
# Task 0:
#     Best Fitness: 839.0225065966679
#     Mean Fitness: 1252.1537008100213
# Task 1:
#     Best Fitness: -701.6064991191671
#     Mean Fitness: -701.5969808960434
# 173.8359375
# --- 0.08 seconds ---
# Gen 180:
# Task 0:
#     Best Fitness: 336.44670487220264
#     Mean Fitness: 594.7469265244525
# Task 1:
#     Best Fitness: -701.6280670174605
#     Mean Fitness: -701.6120999831016
# 173.83984375
# --- 0.08 seconds ---
# import numpy as np
#
# def get_rmp(pop, fitness, skill_factor):
#     n = len(pop)
#     rmp = np.zeros((n, n))
#
#     same_skill = skill_factor[:, None] == skill_factor
#     different_skill = ~same_skill
#
#     pop_norm = pop / np.linalg.norm(pop, axis=1, keepdims=True)
#     cosine_dist = 1 - np.dot(pop_norm, pop_norm.T)
#
#     fitness_diff = np.abs(fitness[:, None] - fitness)
#     fitness_diff_norm = fitness_diff / np.max(fitness_diff)
#
#     rmp_base = 0.5 * (1 - cosine_dist) + 0.5 * (1 - fitness_diff_norm)
#     rmp_base = np.clip(rmp_base, 0, 1)
#
#     rmp[same_skill] = 1.0
#     rmp[different_skill] = rmp_base[different_skill]
#
#     np.fill_diagonal(rmp, 0.0)
#
#     return rmp
# Gen 200:
# Task 0:
#     Best Fitness: -238.9092267575728
#     Mean Fitness: 114.28592992374215
# Task 1:
#     Best Fitness: -701.6438223136897
#     Mean Fitness: -701.6341001749632
# 174.1484375
# --- 14.00 seconds ---
# Gen 220:
# Task 0:
#     Best Fitness: -516.0103120233692
#     Mean Fitness: -281.65662417630216
# Task 1:
#     Best Fitness: -701.6685318450967
#     Mean Fitness: -701.6521413469447
# 174.40234375
# --- 0.07 seconds ---
# Gen 240:
# Task 0:
#     Best Fitness: -706.3485315359653
#     Mean Fitness: -559.1364536446042
# Task 1:
#     Best Fitness: -701.6889535325721
#     Mean Fitness: -701.6736458696132
# 174.4609375
# --- 0.07 seconds ---
# import numpy as np
#
# def get_rmp(pop, fitness, skill_factor):
#     num_tasks = len(np.unique(skill_factor))
#     num_individuals = pop.shape[0]
#
#     same_task = skill_factor[:, None] == skill_factor[None, :]
#     diff_task = ~same_task
#
#     dist = np.sqrt(np.sum((pop[:, None, :] - pop[None, :, :]) ** 2, axis=-1)
#     max_dist = np.max(dist)
#     normalized_dist = dist / max_dist
#
#     fitness_diff = np.abs(fitness[:, None] - fitness[None, :])
#     max_fitness_diff = np.max(fitness_diff)
#     normalized_fitness_diff = fitness_diff / max_fitness_diff
#
#     rmp = np.where(same_task, 1.0, np.exp(-normalized_dist) * (1 - normalized_fitness_diff))
#
#     rmp = np.clip(rmp, 0.05, 0.95)
#     rmp[np.diag_indices(num_individuals)] = 1.0
#
#     return rmp
# Bad Function Generated!
# import numpy as np
# from scipy.spatial.distance import cdist
#
# def get_rmp(pop, fitness, skill_factor):
#     n = len(pop)
#     task_indices = np.unique(skill_factor)
#     num_tasks = len(task_indices)
#     rmp = np.zeros((n, n))
#
#     same_task_mask = skill_factor[:, None] == skill_factor[None, :]
#
#     normalized_fitness = (fitness - np.min(fitness)) / (np.max(fitness) - np.min(fitness) + 1e-10)
#     fitness_similarity = 1.0 / (1.0 + np.abs(normalized_fitness[:, None] - normalized_fitness[None, :]))
#
#     pop_normalized = (pop - np.min(pop, axis=0)) / (np.max(pop, axis=0) - np.min(pop, axis=0) + 1e-10)
#     distance_matrix = cdist(pop_normalized, pop_normalized, 'euclidean')
#     spatial_similarity = 1.0 / (1.0 + distance_matrix)
#
#     rmp_base = np.where(same_task_mask, 1.0, 0.5)
#     rmp_weighted = rmp_base * fitness_similarity * spatial_similarity
#
#     np.fill_diagonal(rmp_weighted, 1.0)
#
#     for i in range(num_tasks):
#         for j in range(i + 1, num_tasks):
#             mask_i = (skill_factor == task_indices[i])
#             mask_j = (skill_factor == task_indices[j])
#             inter_rmp = rmp_weighted[mask_i][:, mask_j]
#             mean_inter_rmp = np.mean(inter_rmp)
#             rmp_weighted[mask_i][:, mask_j] = mean_inter_rmp
#             rmp_weighted[mask_j][:, mask_i] = mean_inter_rmp
#
#     rmp = np.clip(rmp_weighted, 0.1, 0.9)
#
#     return rmp
# Gen 260:
# Task 0:
#     Best Fitness: -845.309169133707
#     Mean Fitness: -757.877016344291
# Task 1:
#     Best Fitness: -701.7044725462322
#     Mean Fitness: -701.6923990168495
# 175.3984375
# --- 0.07 seconds ---
# Gen 280:
# Task 0:
#     Best Fitness: -926.6615715309358
#     Mean Fitness: -858.8810639623816
# Task 1:
#     Best Fitness: -701.7320055921999
#     Mean Fitness: -701.7155258563358
# 176.15234375
# --- 0.07 seconds ---
# import numpy as np
#
# def get_rmp(pop, fitness, skill_factor):
#     num_individuals = pop.shape[0]
#     rmp = np.random.uniform(0.1, 0.9, (num_individuals, num_individuals))
#
#     same_task = skill_factor[:, None] == skill_factor[None, :]
#     diff_task = ~same_task
#
#     normalized_fitness = (fitness - np.min(fitness)) / (np.max(fitness) - np.min(fitness) + 1e-10)
#     fitness_similarity = 1 - np.abs(normalized_fitness[:, None] - normalized_fitness[None, :])
#
#     distances = np.sqrt(np.sum((pop[:, np.newaxis] - pop[np.newaxis, :]) ** 2, axis=-1))
#     max_dist = np.max(distances)
#     if max_dist > 0:
#         distances = distances / max_dist
#
#     similarity = 1 - distances
#     similarity = np.clip(similarity * fitness_similarity, 0, 1)
#
#     rmp[diff_task] = rmp[diff_task] * similarity[diff_task]
#     np.fill_diagonal(rmp, 1.0)
#
#     return rmp
# Gen 300:
# Task 0:
#     Best Fitness: -977.2189238234594
#     Mean Fitness: -933.6655806072118
# Task 1:
#     Best Fitness: -701.7669489132145
#     Mean Fitness: -701.742537734083
# 176.26171875
# --- 16.54 seconds ---
# Gen 320:
# Task 0:
#     Best Fitness: -1010.4662214648549
#     Mean Fitness: -976.835678274236
# Task 1:
#     Best Fitness: -701.8026829289968
#     Mean Fitness: -701.7699585285177
# 176.359375
# --- 0.09 seconds ---
# Gen 340:
# Task 0:
#     Best Fitness: -1034.4896312383578
#     Mean Fitness: -1004.6309725308972
# Task 1:
#     Best Fitness: -701.8334513149315
#     Mean Fitness: -701.8024415542219
# 176.4453125
# --- 0.09 seconds ---
# import numpy as np
#
# def get_rmp(pop, fitness, skill_factor):
#     num_tasks = len(np.unique(skill_factor))
#     num_individuals = pop.shape[0]
#     rmp = np.zeros((num_individuals, num_individuals))
#
#     same_task = skill_factor[:, None] == skill_factor[None, :]
#
#     normalized_pop = (pop - np.min(pop, axis=0)) / (np.max(pop, axis=0) - np.min(pop, axis=0)
#     euclidean_dist = np.sqrt(np.sum((normalized_pop[:, None, :] - normalized_pop[None, :, :]) ** 2, axis=-1))
#     normalized_dist = euclidean_dist / np.max(euclidean_dist)
#
#     fitness_diff = np.abs(fitness[:, None] - fitness[None, :])
#     normalized_fitness_diff = fitness_diff / np.max(fitness_diff)
#
#     alpha = 0.5
#     beta = 0.5
#     gamma = 0.5
#
#     task_matrix = 1.0 - same_task.astype(float)
#     distance_matrix = 1.0 - normalized_dist
#     fitness_matrix = 1.0 - normalized_fitness_diff
#
#     rmp = gamma * task_matrix + alpha * distance_matrix + beta * fitness_matrix
#     rmp = np.clip(rmp, 0.0, 1.0)
#
#     np.fill_diagonal(rmp, 1.0)
#
#     return rmp
# Bad Function Generated!
# import numpy as np
#
# def get_rmp(pop, fitness, skill_factor):
#     num_ind = pop.shape[0]
#     rmp = np.zeros((num_ind, num_ind))
#
#     skill_mask = (skill_factor[:, None] == skill_factor)
#     same_skill = skill_mask.astype(float)
#
#     normalized_pop = (pop - np.mean(pop, axis=0)) / (np.std(pop, axis=0) + 1e-10)
#     dist = np.sqrt(np.sum((normalized_pop[:, None, :] - normalized_pop[None, :, :])**2, axis=-1))
#     normalized_dist = (dist - np.min(dist)) / (np.max(dist) - np.min(dist) + 1e-10)
#
#     fitness_diff = np.abs(fitness[:, None] - fitness[None, :])
#     normalized_fitness = (fitness_diff - np.min(fitness_diff)) / (np.max(fitness_diff) - np.min(fitness_diff) + 1e-10)
#
#     alpha = 0.5
#     rmp = np.exp(-alpha * (normalized_dist + normalized_fitness))
#     rmp = rmp * np.logical_not(same_skill)
#
#     np.fill_diagonal(rmp, 0)
#
#     return rmp
# Gen 360:
# Task 0:
#     Best Fitness: -1044.850545400613
#     Mean Fitness: -1024.085187384612
# Task 1:
#     Best Fitness: -701.8649260398536
#     Mean Fitness: -701.8343350678145
# 180.1484375
# --- 0.09 seconds ---
# Gen 380:
# Task 0:
#     Best Fitness: -1060.0374402001564
#     Mean Fitness: -1040.037374725907
# Task 1:
#     Best Fitness: -701.8808847733219
#     Mean Fitness: -701.8583413628116
# 180.30859375
# --- 0.10 seconds ---
# import numpy as np
#
# def get_rmp(pop, fitness, skill_factor):
#     num_individuals = pop.shape[0]
#     rmp = np.zeros((num_individuals, num_individuals))
#
#     same_skill = skill_factor[:, None] == skill_factor[None, :]
#
#     norm_pop = pop / np.linalg.norm(pop, axis=1, keepdims=True)
#     cosine_dist = 1 - np.dot(norm_pop, norm_pop.T)
#
#     fitness_diff = np.abs(fitness[:, None] - fitness[None, :])
#     fitness_diff_norm = fitness_diff / np.max(fitness_diff)
#
#     diversity_factor = 1 - np.exp(-cosine_dist)
#
#     rmp = np.where(
#         same_skill,
#         1.0,
#         np.clip(diversity_factor * (1 - fitness_diff_norm), 0, 1
#     )
#
#     np.fill_diagonal(rmp, 0)
#
#     return rmp
# Bad Function Generated!
# import numpy as np
# from scipy.spatial.distance import cdist
#
# def get_rmp(pop, fitness, skill_factor):
#     num_tasks = len(np.unique(skill_factor))
#     population_size = len(pop)
#     rmp = np.zeros((population_size, population_size))
#
#     same_task_mask = skill_factor[:, None] == skill_factor
#
#     normalized_pop = (pop - np.min(pop, axis=0)) / (np.max(pop, axis=0) - np.min(pop, axis=0) + 1e-12
#     distances = cdist(normalized_pop, normalized_pop, 'euclidean')
#     max_dist = np.max(distances)
#     normalized_dist = distances / max_dist
#
#     fitness_diff = np.abs(fitness[:, None] - fitness)
#     max_fitness_diff = np.max(fitness_diff)
#     normalized_fitness_diff = fitness_diff / (max_fitness_diff + 1e-12)
#
#     rmp = np.exp(-normalized_dist) * np.exp(-normalized_fitness_diff)
#     rmp = np.clip(rmp, 0.3, 0.9)
#     rmp[same_task_mask] = 1.0
#     np.fill_diagonal(rmp, 0.0)
#
#     return rmp
# Bad Function Generated!
# import numpy as np
#
# def get_rmp(pop, fitness, skill_factor):
#     num_tasks = len(np.unique(skill_factor))
#     num_inds = pop.shape[0]
#     dim = pop.shape[1]
#
#     skill_mask = (skill_factor[:, None] == skill_factor[None, :])
#     same_skill = skill_mask.astype(float)
#
#     normalized_pop = (pop - np.min(pop, axis=0)) / (np.max(pop, axis=0) - np.min(pop, axis=0) + 1e-10)
#     dist = np.sqrt(np.sum((normalized_pop[:, None, :] - normalized_pop[None, :, :]) ** 2, axis=-1))
#     max_dist = np.max(dist)
#     normalized_dist = dist / max_dist if max_dist > 0 else dist
#
#     rmp = np.exp(-normalized_dist * num_tasks)
#     rmp = rmp * same_skill
#     np.fill_diagonal(rmp, 0)
#
#     return rmp
# Gen 400:
# Task 0:
#     Best Fitness: -1066.8579624111048
#     Mean Fitness: -1051.5649676371786
# Task 1:
#     Best Fitness: -701.9083399044216
#     Mean Fitness: -701.8799547640639
# 180.41796875
# --- 43.01 seconds ---
# Gen 420:
# Task 0:
#     Best Fitness: -1068.4690274274556
#     Mean Fitness: -1059.5337104680068
# Task 1:
#     Best Fitness: -701.9301752583405
#     Mean Fitness: -701.9030321479437
# 175.96875
# --- 0.14 seconds ---
# Gen 440:
# Task 0:
#     Best Fitness: -1074.027490266606
#     Mean Fitness: -1065.9288099170926
# Task 1:
#     Best Fitness: -701.9425146044745
#     Mean Fitness: -701.9218479339916
# 175.3203125
# --- 0.10 seconds ---
# import numpy as np
#
# def get_rmp(pop, fitness, skill_factor):
#     num_tasks = len(np.unique(skill_factor))
#     population_size = len(pop)
#     rmp = np.zeros((population_size, population_size))
#
#     same_task_mask = skill_factor[:, None] == skill_factor
#     different_task_mask = ~same_task_mask
#
#     norm_pop = (pop - np.min(pop, axis=0)) / (np.max(pop, axis=0) - np.min(pop, axis=0) + 1e-10)
#     distances = np.sqrt(np.sum((norm_pop[:, None, :] - norm_pop[None, :, :]) ** 2, axis=2))
#     avg_dist = np.mean(distances)
#     scaled_dist = distances / (avg_dist + 1e-10)
#
#     fitness_diff = np.abs(fitness[:, None] - fitness[None, :])
#     max_fitness_diff = np.max(fitness_diff)
#     scaled_fitness = fitness_diff / (max_fitness_diff + 1e-10)
#
#     rmp[different_task_mask] = np.exp(-scaled_dist[different_task_mask]) * (1 - scaled_fitness[different_task_mask])
#     rmp[same_task_mask] = 1.0
#
#     np.fill_diagonal(rmp, 0.0)
#     return rmp
# Gen 460:
# Task 0:
#     Best Fitness: -1074.750303938195
#     Mean Fitness: -1070.717544095867
# Task 1:
#     Best Fitness: -701.9568899199065
#     Mean Fitness: -701.9386673086665
# 174.296875
# --- 0.22 seconds ---
# Gen 480:
# Task 0:
#     Best Fitness: -1076.1360163999625
#     Mean Fitness: -1073.4967115721824
# Task 1:
#     Best Fitness: -701.9850160558583
#     Mean Fitness: -701.9551781514637
# 174.421875
# --- 0.22 seconds ---
# import numpy as np
#
# def get_rmp(pop, fitness, skill_factor):
#     num_tasks = np.unique(skill_factor).size
#     num_individuals = pop.shape[0]
#
#     skill_mask = (skill_factor[:, None] == skill_factor)
#     task_indices = skill_factor[:, None] * num_tasks + skill_factor
#
#     pairwise_dist = np.sqrt(np.sum((pop[:, None, :] - pop) ** 2, axis=2))
#     normalized_dist = pairwise_dist / np.max(pairwise_dist)
#
#     fitness_diff = np.abs(fitness[:, None] - fitness)
#     normalized_fitness = fitness_diff / np.max(fitness_diff)
#
#     diversity_factor = 1.0 - 0.5 * (normalized_dist + normalized_fitness)
#
#     rmp_matrix = np.where(
#         skill_mask,
#         diversity_factor,
#         diversity_factor * np.random.rand(num_individuals, num_individuals)
#
#     np.fill_diagonal(rmp_matrix, 0.0)
#
#     return rmp_matrix
# Bad Function Generated!
# import numpy as np
#
# def get_rmp(pop, fitness, skill_factor):
#     num_tasks = len(np.unique(skill_factor))
#     population_size = pop.shape[0]
#
#     normalized_fitness = (fitness - np.min(fitness, axis=0)) / (np.max(fitness, axis=0) - np.min(fitness, axis=0) + 1e-10)
#     fitness_similarity = 1.0 / (1.0 + np.abs(normalized_fitness[:, None] - normalized_fitness))
#
#     normalized_pop = (pop - np.min(pop, axis=0)) / (np.max(pop, axis=0) - np.min(pop, axis=0) + 1e-10)
#     euclidean_dist = np.sqrt(np.sum((normalized_pop[:, None, :] - normalized_pop) ** 2, axis=2))
#     euclidean_similarity = 1.0 / (1.0 + euclidean_dist)
#
#     sf_matrix = skill_factor[:, None] == skill_factor
#     same_task_mask = sf_matrix.astype(float)
#     diff_task_mask = 1.0 - same_task_mask
#
#     task_similarity = 0.5 * same_task_mask + 0.5 * diff_task_mask / (num_tasks - 1)
#
#     combined_similarity = (0.4 * fitness_similarity + 0.4 * euclidean_similarity + 0.2 * task_similarity)
#     np.fill_diagonal(combined_similarity, 0)
#
#     rmp = np.random.rand(population_size, population_size)
#     rmp = rmp * combined_similarity
#
#     return rmp
# Gen 500:
# Task 0:
#     Best Fitness: -1077.2128363156983
#     Mean Fitness: -1075.3094822039823
# Task 1:
#     Best Fitness: -701.9995867653836
#     Mean Fitness: -701.9724316955143
# 174.59375
# --- 33.34 seconds ---

# %%
#test
for task_id in range(len(tasks)):
    print("Task {0} optimal value : {1}".format(task_id, tasks[task_id].OptimumValue))
# Out:
# Task 0 optimal value : -1081.9837994003399
# Task 1 optimal value : -703.1328146165181
# Task 2 optimal value : -884.7360096017693
# Task 3 optimal value : -604.9748272222274
# Task 4 optimal value : -5000
# Task 5 optimal value : -5000
